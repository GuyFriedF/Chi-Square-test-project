# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
from scipy import stats

# %%
url = 'https://drive.google.com/file/d/1Tj6Z4OtJqLBOW0z2fvuGS5EhZo8xTVM6/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
interact_df = pd.read_csv(path)

# Element list Homepage Version 2 - Connect, 5-29-2013.csv
url = 'https://drive.google.com/file/d/1qHBdOjUWvJpN-LTg1z2jpeA3mDXQjdch/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
connect_df = pd.read_csv(path)

# Element list Homepage Version 3 - Learn, 5-29-2013.csv
url = 'https://drive.google.com/file/d/1g8prRmy3hpVtL6zvkdCwXcgIV0CS48zr/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
learn_df = pd.read_csv(path)

# Element list Homepage Version 4 - Help, 5-29-2013.csv
url = 'https://drive.google.com/file/d/1I9bjXkxtiILDogeQmsWCCDlQtRZ8OSrs/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
help_df = pd.read_csv(path)

# Element list Homepage Version 5 - Services, 5-29-2013.csv
url = 'https://drive.google.com/file/d/1noDp_jpdAL_LGxU3SPDxqP94pUCqisqW/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
services_df = pd.read_csv(path)

# %%
#Experimenting with ctr-values and clicks vs. no-clicks ratios for the different tables, not relevant eventually for this project

connect_ctr = connect_df.loc[connect_df['Name']=='CONNECT', 'No. clicks'] / connect_df['No. clicks'].sum()
connect_clicks = connect_df.loc[connect_df['Name']=='CONNECT','No. clicks']
connect_noclicks = connect_df['No. clicks'].sum() - connect_df.loc[connect_df['Name']=='CONNECT']['No. clicks']

help_ctr = help_df.loc[help_df['Name']=='HELP', 'No. clicks'] / help_df['No. clicks'].sum()
help_clicks = help_df.loc[help_df['Name']=='HELP']['No. clicks']
help_noclicks = help_df['No. clicks'].sum() - help_df.loc[help_df['Name']=='HELP']['No. clicks']

learn_ctr = learn_df.loc[learn_df['Name']=='LEARN', 'No. clicks'] / learn_df['No. clicks'].sum()
learn_clicks = learn_df.loc[learn_df['Name']=='LEARN']['No. clicks']
learn_noclicks = learn_df['No. clicks'].sum() - learn_df.loc[learn_df['Name']=='LEARN']['No. clicks']

services_ctr = services_df.loc[services_df['Name']=='SERVICES', 'No. clicks'] / services_df['No. clicks'].sum()
services_clicks = services_df.loc[services_df['Name']=='SERVICES']['No. clicks']
services_noclicks = services_df['No. clicks'].sum() - services_df.loc[services_df['Name']=='SERVICES']['No. clicks']

interact_ctr = interact_df.loc[interact_df['Name']=='INTERACT', 'No. clicks'] / interact_df['No. clicks'].sum()
interact_clicks = interact_df.loc[interact_df['Name']=='INTERACT']['No. clicks']
interact_noclicks = interact_df['No. clicks'].sum() - interact_df.loc[interact_df['Name']=='INTERACT']['No. clicks']

# %%
#Extracting Data manually from different datasets and creating a Dictionary
MSUData = {'Clicks':[53,38,21,45,42], 'No Clicks':[2689,3142,2726,2019,10241]}

# %%
#Creating a new DataFrame out of the dictionary, with corresponding columnm names
MSUData_df = pd.DataFrame.from_dict(MSUData, orient='index',
                       columns=['Connect', 'Help', 'Learn', 'Services', 'Interact'])

# %%
#Running the chi-square test
chisq, pvalue, df, expected = chi2_contingency(MSUData_df)

# %%
#recieving the p-value
pvalue
# Out:
# 4.852334301093838e-20

# %% [markdown]
# P-value is low, so the null (hypothesis) must go!
